# %% [markdown]
# # Intro to Programming with Python

# %% [markdown]
# ## PyLadies San Diego
# ##at GeekGirl Tech Conference
# ##San Diego, June 2015.

# %% [markdown]
# ##Carol Willing
#
# - Willing Consulting, Developer  https://willingconsulting.com
# - Fab Lab San Diego, Geek in Residence https://fablabsd.org
# - Python Software Foundation, Director https://python.org
#
# - GitHub: willingc, Twitter: @willingcarol

# %% [markdown]
# ## Remember the tortoise and the hare?
# Turtles in Python

# %%
# From Python Standard Library Documentation
from turtle import *
color('red', 'yellow')
begin_fill()
while True:
    forward(200)
    left(170)
    if abs(pos()) < 1:
        break
end_fill()
done()

# %%
from turtle import *
color('blue', 'green')
begin_fill()
while True:
    forward(200)
    left(170)
    if abs(pos()) < 1:
        break
end_fill()
done()

# %%
# http://www.greenteapress.com/thinkpython/thinkpython.html

# %% [markdown]
# ## Images
# Machine learning sci-kit-image

# %%
# Set up
import numpy as np
import matplotlib.pyplot as plt
import skimage.exposure as skie
# %matplotlib inline

# %%
# Gather data
img = plt.imread('piespot.jpg')[...,0]

# %%
# Display visual function
def show(img):
    plt.subplot(121)
    plt.imshow(img, cmap=plt.cm.gray)
    plt.axis('off')
    plt.subplot(122)
    plt.hist(img.ravel(), lw=0, bins=256)
    plt.xlim(0, img.max())
    plt.yticks([])
    plt.show()

# %%
# Share - Display visual
show(img)

# %%
# Analyze
show(skie.rescale_intensity(img,
                           in_range=(100, 240), out_range=(0, 255)))

# %%
# Share - Display visual
show(skie.equalize_adapthist(img))
# Out:
# /usr/local/opt/pyenv/versions/anaconda3-2.1.0/lib/python3.4/site-packages/skimage/util/shape.py:92: RuntimeWarning: Cannot provide views on a non-contiguous input array without copying.
#   warn(RuntimeWarning("Cannot provide views on a non-contiguous input "

# %%
# Set up
import numpy as np
import matplotlib.pyplot as plt
import skimage
import skimage.filter as skif
import skimage.data as skid
# %matplotlib inline

# %%
def show_gray(img):
    plt.imshow(img, cmap=plt.cm.gray)
    plt.axis('off')
    plt.show()

# %%
img = skimage.img_as_float(('piespot.jpg'), True)[...,0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-377b1cdc9e11> in <module>()
# ----> 1 img = skimage.img_as_float(('piespot.jpg'), True)[...,0]
#
# /usr/local/opt/pyenv/versions/anaconda3-2.1.0/lib/python3.4/site-packages/skimage/util/dtype.py in img_as_float(image, force_copy)
#     285
#     286     """
# --> 287     return convert(image, np.float64, force_copy)
#     288
#     289
#
# /usr/local/opt/pyenv/versions/anaconda3-2.1.0/lib/python3.4/site-packages/skimage/util/dtype.py in convert(image, dtype, force_copy, uniform)
#      97
#      98     if not (dtype_in in _supported_types and dtype in _supported_types):
# ---> 99         raise ValueError("can not convert %s to %s." % (dtypeobj_in, dtypeobj))
#     100
#     101     def sign_loss():
#
# ValueError: can not convert <U11 to float64.

# %% [markdown]
# ##Music
# inspired by Cyrille Rossant's Piano example

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import (Audio, display, clear_output)
from IPython.html import widgets
from functools import partial
# %matplotlib inline
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
# Gather data
rate = 16000.
duration = 0.25
t = np.linspace(0., duration, rate * duration)

# %%
# Analyze
def synth(f):
    x = np.sin(f * 2. * np.pi * t)
    display(Audio(x, rate=rate, autoplay=True))

# %%
# Display - Play audio
synth(440)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Gather and Analyze
notes = zip(('C,C#,D,D#,E,F,F#,G,G#,'
            'A,A#,B,C').split(','),
            440. * 2 ** (np.arange(3, 17) / 12.))

# %%
# Display
my_box = widgets.Box()
buttons = []
for note, f in notes:
    button = widgets.Button(description=note)
    def on_button_clicked(f, b):
        clear_output()
        synth(f)
    button.on_click(partial(on_button_clicked, f))
    button.width = '30px'
    button.height = '60px'
    button.padding = '0'
    button.color = ('black', 'white')['#' in note]
    button.background_color = ('white', 'black')['#' in note]
    button.border_color = 'black'
    button.border_style = 'solid'
    button.border_width = '1px'
    buttons.append(button)
my_box.children = buttons
display(my_box)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Change the duration of the note
# Quarter notes

# %% [markdown]
# ##Interactive teaching
# Lorena Barba

# %% [markdown]
# http://nbviewer.ipython.org/github/numerical-mooc/numerical-mooc/blob/master/lessons/01_phugoid/01_01_Phugoid_Theory.ipynb

# %% [markdown]
# ##Web scraping

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://www.willingconsulting.com")
bsObj = BeautifulSoup(html.read());
print(bsObj.h1)
# Out:
# <h1 class="site-title">
# <a href="https://willingconsulting.com/" rel="home">Willing Consulting</a>
# </h1>

# %%
print(bsObj.h2)
# Out:
# <h2 class="site-description">Learn. Build. Share. — Openly</h2>

# %%
html = urlopen("http://sandiego.gov")
bsObj = BeautifulSoup(html.read())
print(bsObj.h2)
# Out:
# <h2>Most Requested Links</h2>

# %%
print(bsObj.h4)
# Out:
# <h4 style="text-transform: none;">Faulconer Signs 2016 One San Diego Budget into Law</h4>

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get("http://www.willingconsulting.com")
c = response.content
bsObj = BeautifulSoup(c)
print(bsObj.h1)

# %%
print(bsObj)

# %%
print(bsObj.footer)

# %%
print(bsObj.header)

# %%
print(bsObj.header.prettify)

# %%
from PIL import Image, ImageFilter

pie = Image.open("piespot.jpg")
blurryPie = pie.filter(ImageFilter.GaussianBlur)
blurryPie.save("pie_blurred.jpg")
blurryPie.show()

# %% [markdown]
# #Birds!!!

# %%
from PIL import Image, ImageFilter

bird = Image.open("bird.jpg")
blurryBird = bird.filter(ImageFilter.GaussianBlur)
blurryBird.save("bird_blurred.jpg")
blurryBird.show()

# %%
from PIL import Image, ImageOps

bird = Image.open("bird.jpg")
upsideBird = ImageOps.flip(bird)
upsideBird.save("bird_upside.jpg")
upsideBird.show()

# %%
from PIL import Image, ImageOps

bird = Image.open("bird.jpg")
invertBird = ImageOps.invert(bird)
invertBird.save("bird_invert.jpg")
invertBird.show()
